# %%
def update_files():
    ! cd E:\DMS625
    # !git add .
    ! git commit -m "Added new files and updates"
    # !git push origin main

# %%
update_files()
# Out:
# ...
# [main 5318fc3] Added new files and updates
#  13 files changed, 2631 insertions(+), 65 deletions(-)
#  create mode 100644 .ipynb_checkpoints/CAPM-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/sbi_main_re-checkpoint.csv
#  create mode 100644 CAPM.ipynb
#  create mode 100644 Treasury Bills Cut Off Yield Auction 91 Days.xlsx
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 classical_matlab.m
#  create mode 100644 classical_simulation_image.png
#  create mode 100644 sbi_main_re.csv
# git: 'credential-manager-core' is not a git command. See 'git --help'.
# To https://github.com/035skt/DMS625.git
#    01cf367..5318fc3  main -> main
