# %%
def update_files():
    ! cd E:\DMS625
    # !git add .
    ! git commit -m "Added new files and updates"
    # !git push origin main

# %%
update_files()
# Out:
# ...
# [main 19615b9] Added new files and updates
#  3 files changed, 155 insertions(+), 24 deletions(-)
# git: 'credential-manager-core' is not a git command. See 'git --help'.
# To https://github.com/035skt/DMS625.git
#    a50fee7..19615b9  main -> main
